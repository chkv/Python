# %% [markdown]
# nyc_weather.csv contains new york city weather for first few days in the month of January. Write a program that can answer following,

# %% [markdown]
# What was the average temperature in first week of Jan

# %%
with open("/users/CHKV/Downloads/nyc_weather.csv","r") as f:
    # print(f.read())
    temp_list=[]
    next(f)
    for temp in f:
        t=[]
        t=temp.split(",")
        temp_list.append(int(t[1]))

    print(temp_list)
# Out:
# [27, 31, 23, 34, 37, 38, 29, 30, 35, 30]

# %%
avg_first_week=sum(temp_list[0:7])/7
print(round(avg_first_week,2))
# Out:
# 31.29

# %% [markdown]
# What was the maximum temperature in first 10 days of Jan
# Figure out data structure that is best for this problem

# %%
index=max((range(0,10)),key=lambda x: temp_list[x])
print(temp_list[index])
# Out:
# 38

# %% [markdown]
# nnyc_weather.csv contains new york city weather for first few days in the month of January. Write a program that can answer following,
# - What was the temperature on Jan 9?

# %%
with open("/users/CHKV/downloads/nyc_weather.csv","r") as f:
   # print(f.read())
    temp_dict={}
    next(f)
    for temp in f:
        t=temp.split(",")
        temp_dict[t[0]]=int(t[1])

print(temp_dict.items())

# %%
temp_dict['Jan 9']
# Out:
# 35

# %% [markdown]
# - What was the temperature on Jan 4?
# Figure out data structure that is best for this problem

# %%
temp_dict['Jan 4']
# Out:
# 34

# %% [markdown]
# poem.txt Contains famous poem "Road not taken" by poet Robert Frost. You have to read this file in python and print every word and its count as show below. Think about the best data structure that you can use to solve this problem and figure out why you selected that specific data structure.
#  - 'diverged': 2,
#  - 'in': 3,
#  - 'I': 8

# %%
with open("/users/CHKV/downloads/poem.txt","r") as f:
    word_count={}
    for line in f:
        tokens=line.split(" ")
        for token in tokens:
            token=token.replace('\n','')
            if token in word_count:
                word_count[token]+=1
            else:
                word_count[token]=1
    print(word_count.items())

    print(word_count.get('I'))
    print(max(word_count.keys(),key=word_count.get))
# Out:
# dict_items([('Two', 2), ('roads', 2), ('diverged', 2), ('in', 3), ('a', 3), ('yellow', 1), ('wood,', 2), ('And', 6), ('sorry', 1), ('I', 8), ('could', 2), ('not', 1), ('travel', 1), ('both', 2), ('be', 2), ('one', 3), ('traveler,', 1), ('long', 1), ('stood', 1), ('looked', 1), ('down', 1), ('as', 5), ('far', 1), ('To', 1), ('where', 1), ('it', 2), ('bent', 1), ('the', 8), ('undergrowth;', 1), ('', 3), ('Then', 1), ('took', 2), ('other,', 1), ('just', 1), ('fair,', 1), ('having', 1), ('perhaps', 1), ('better', 1), ('claim,', 1), ('Because', 1), ('was', 1), ('grassy', 1), ('and', 3), ('wanted', 1), ('wear;', 1), ('Though', 1), ('for', 2), ('that', 3), ('passing', 1), ('there', 1), ('Had', 1), ('worn', 1), ('them', 1), ('really', 1), ('about', 1), ('same,', 1), ('morning', 1), ('equally', 1), ('lay', 1), ('In', 1), ('leaves', 1), ('no', 1), ('step', 1), ('had', 1), ('trodden', 1), ('black.', 1), ('Oh,', 1), ('kept', 1), ('first', 1), ('another', 1), ('day!', 1), ('Yet', 1), ('knowing', 
# ...
