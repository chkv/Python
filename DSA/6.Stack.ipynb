# %% [markdown]
# - Data structure tutorial exercise: Stack
# Write a function in python that can reverse a string using stack data structure. Use Stack class from the tutorial.
# - reverse_string("We will conquere COVID-19") should return "91-DIVOC ereuqnoc lliw eW"

# %%
from collections import deque
class Stack:
    def __init__(self):
        self.container=deque()

    def push(self,value):
        self.container.append(value)

    def pop(self):
        return self.container.pop()

    def peek(self):
        return self.container[-1]

    def get_length(self):
        return  len(self.container)

    def is_empty(self):
        return len(self.container) == 0

# %%
def reverse(str):
    stack=Stack()
    for char in str:
        stack.push(char)
    rstr=''
    while stack.get_length()!=0:
        rstr+=stack.pop()+ ""

    return rstr

# %%
reverse("We will conquere COVID-19")
# Out:
# '91-DIVOC ereuqnoc lliw eW'

# %% [markdown]
# Write a function in python that checks if paranthesis in the string are balanced or not. Possible parantheses are "{}',"()" or "[]". Use Stack class from the tutorial.
# - is_balanced("({a+b})")     --> True
# - is_balanced("))((a+b}{")   --> False
# - is_balanced("((a+b))")     --> True
# - is_balanced("))")          --> False
# - is_balanced("[a+b]*(x+2y)*{gg+kk}") --> True

# %%
def is_matched(open_bracket, close_bracket):
    match_dict = {
        "{": "}",
        "(": ")",
        "[": "]"
    }
    return match_dict[open_bracket] == close_bracket


def is_balanced(s):
    stack = Stack()

    for ch in s:
        if ch in "{([":
            stack.push(ch)

        elif ch in ")}]":
            if stack.is_empty():
                return False

            if not is_matched(stack.pop(), ch):
                return False

    return stack.is_empty()

# %%
is_balanced("({a+b})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 is_balanced("({a+b})")
#
# Cell In[1], line 11, in is_balanced(s)
#      10 def is_balanced(s):
# ---> 11     stack = Stack()
#      13     for ch in s:
#      14         if ch in "{([":
#
# NameError: name 'Stack' is not defined

# %%
is_balanced("))((a+b}{")
# Out:
# False

# %%
is_balanced("((a+b))")
# Out:
# True

# %%
is_balanced("))")
# Out:
# False

# %%
is_balanced("[a+b]*(x+2y)*{gg+kk}")
# Out:
# True

# %%
from collections import deque
class Stack:
    def __init__(self):
        self.arr=deque()
    def push(self,value):
        self.arr.append(value)

    def peek(self):
        return self.arr[-1]

    def get_length(self):
        return len(self.arr)

    def pop(self):
        return self.arr.pop()

    def is_empty(self):
        return len(self.arr)==0

# %%
def is_matched(open_bracket, close_bracket):
    dict={"(":")","{":"}","[":"]"}
    if dict[open_bracket]==close_bracket:
        return True
    return False

# %%
def is_balanced(stri):
    stack=Stack()
    for ch in stri:
        if ch=="{" or ch=="[" or ch=="(":
            stack.push(ch)
        if ch=="}" or ch=="]" or ch==")":
            if stack.is_empty():
                return False
            if not is_matched(stack.pop(),ch):
                return False
    return stack.is_empty()

# %% [markdown]
# - is_balanced("({a+b})")     --> True
# - is_balanced("))((a+b}{")   --> False
# - is_balanced("((a+b))")     --> True
# - is_balanced("))")          --> False
# - is_balanced("[a+b]*(x+2y)*{gg+kk}") --> True

# %%
is_balanced("({a+b})")
# Out:
# True

# %%
is_balanced("))((a+b}{")
# Out:
# False

# %%
is_balanced("((a+b))")
# Out:
# True

# %%
is_balanced("))")
# Out:
# False

# %%
is_balanced("[a+b]*(x+2y)*{gg+kk}")
# Out:
# True
